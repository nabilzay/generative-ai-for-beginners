# %% [markdown]
# The following notebook was auto-generated by GitHub Copilot Chat and is meant for initial setup only

# %% [markdown]
# # Introduction to Prompt Engineering
# Prompt engineering is the process of designing and optimizing prompts for natural language processing tasks. It involves selecting the right prompts, tuning their parameters, and evaluating their performance. Prompt engineering is crucial for achieving high accuracy and efficiency in NLP models. In this section, we will explore the basics of prompt engineering using the OpenAI models for exploration.

# %% [markdown]
# ### Exercise 1: Tokenization
# Explore Tokenization using tiktoken, an open-source fast tokenizer from OpenAI
# See [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) for more examples.

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-4o")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]

# %% [markdown]
# ### Exercise 2: Validate OpenAI API Key Setup
#
# Run the code below to verify that your OpenAI endpoint is set up correctly. The code just tries a simple basic prompt and validates the completion. Input `oh say can you see` should complete along the lines of `by the dawn's early light..`

# %%
# Uses the OpenAI client with the Responses API.
# See https://platform.openai.com/docs/api-reference/responses

import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

deployment="gpt-5.4-mini"

def get_completion(prompt):
    response = client.responses.create(
        model=deployment,
        input=prompt,
        max_output_tokens=1024,
        store=False,
    )
    return response.output_text

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)
# Out:
# The opening line is from **“The Star-Spangled Banner”**, the national anthem of the United States.
#
# Full opening:
# **“O say can you see, by the dawn’s early light…”**

# %% [markdown]
# ### Exercise 3: Fabrications
# Explore what happens when you ask the LLM to return completions for a prompt about a topic that may not exist, or about topics that it may not know about because it was outside it's pre-trained dataset (more recent). See how the response changes if you try a different prompt, or a different model.

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)
# Out:
# Sure — here’s a **fictional lesson plan** for the **Martian War of 2076**.
#
# ---
#
# # Lesson Plan: The Martian War of 2076
#
# ## Grade Level
# Middle School or High School
#
# ## Subject
# History / Science Fiction Studies / World Studies
#
# ## Lesson Duration
# 1–2 class periods
#
# ## Learning Objectives
# By the end of the lesson, students will be able to:
# - Describe the main causes of the Martian War of 2076.
# - Identify key events and turning points in the conflict.
# - Analyze the effects of the war on Earth–Mars relations.
# - Evaluate how technology, resources, and politics shaped the war.
# - Compare the fictional conflict to real historical wars.
#
# ## Materials
# - Whiteboard or projector
# - Timeline handout
# - Map of Earth and Mars colonies
# - Primary-source style excerpts or fictional news reports
# - Paper and pens or digital devices
#
# ## Key Vocabulary
# - Colony
# - Terraforming
# - Resource conflict
# - Ceasefire
# - Sovereignty
# - Occupation
# - Diplomacy
#
# ---
#
# ## Lesson Introduction (10 minutes)
# Begin with a discussion prompt:
#
# **“What could cause a war between Earth and Mars?”**
#
# Ask students to brainstorm possible reasons, such as:
# - Water shortages
# - Mining rights
# - Political independence
# - Control of life-support systems
# - Trade disputes
#
# Explain that the Martian War of 2076 was a fictional conflict used to explore themes of colonization, survival, and governance.
#
# ---
#
# ## Direct Instruction (15–20 minutes)
# Provide a brief overview of the war:
#
# ### Background
# - By 2076, Mars had several large human settlements.
# - Tensions grew between Mars-based leaders and Earth governments over control of resources.
# - Mars wanted greater autonomy, while Earth wanted to regulate trade and security.
# - A dispute over helium-3 mining and water extraction triggered open conflict.
#
# ### Major Events
# 1. **The Port Olympus Blockade**
#    Earth forces attempted to cut off supply routes to Martian cities.
#
# 2. **The Ares Uprising**
#    Martian settlers resisted Earth control and seized communication hubs.
#
# 3. **The Siege of Valles Station**
#    One of the largest battles of the war, centered on a critical energy facility.
#
# 4. **The Treaty of New Dawn**
#    The war ended with negotiations granting Mars partial independence and shared resource rights.
#
# ---
#
# ## Guided Activity (20 minutes)
# ### Timeline Creation
# Divide students into small groups. Give each group event cards or a list of key moments from the war. Ask them to:
# - Put the events in chronological order
# - Add a short description of each event
# - Identify which events were political, military, or economic
#
# ### Discussion Questions
# - Who had the stronger position at the beginning of the war?
# - Why were supplies and infrastructure so important?
# - Could the war have been avoided? Why or why not?
# - What role did diplomacy play in ending the conflict?
#
# ---
#
# ## Independent Activity (15–20 minutes)
# ### Writing Assignment
# Ask students to write a short response to one of the following prompts:
#
# 1. **How did resource scarcity contribute to the Martian War of 2076?**
# 2. **Was Mars justified in seeking independence? Explain your answer.**
# 3. **What lessons can be learned from the war about cooperation in space?**
#
# Students should use at least 3 vocabulary words in their response.
#
# ---
#
# ## Assessment
# Assess students based on:
# - Participation in discussion
# - Accuracy and completeness of timeline
# - Quality of written response
# - Use of evidence and vocabulary
#
# ## Differentiation
# - Provide sentence starters for struggling writers.
# - Allow advanced students to research and create an alternate treaty proposal.
# - Use visual supports such as maps and diagrams for English language learners.
#
# ## Extension Activity
# Have students design:
# - A newspaper front page reporting the end of the war
# - A peace treaty between Earth and Mars
# - A memorial honoring those affected by the conflict
#
# ---
#
# ## Closure (5 minutes)
# End with a reflection question:
#
# **“If humans live on other planets in the future, what rules should be in place to prevent wars like the Martian War of 2076?”**
#
# ---
#
# If you want, I can also turn this into:
# - a **one-day lesson plan**
# - a **full unit plan**
# - a **worksheet or student handout**
# - or a version written in a more **realistic academic style**

# %% [markdown]
# ### Exercise 4: Instruction Based
# Use the "text" variable to set the primary content
# and the "prompt" variable to provide an instruction related to that primary content.
#
# Here we ask the model to summarize the text for a second-grade student

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Exercise 5: Complex Prompt
# Try a request that has system, user and assistant messages
# System sets assistant context
# User & Assistant messages provide multi-turn conversation context
#
# Note how the assistant personality is set to "sarcastic" in the system context.
# Try using a different personality context. Or try a different series of input/output messages

# %%
response = client.responses.create(
    model=deployment,
    input=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ],
    store=False,
)
print(response.output_text)
# Out:
# The 2020 World Series was played at Globe Life Field in Arlington, Texas. Because apparently even baseball needed a bubble year.

# %% [markdown]
# ### Exercise: Explore Your Intuition
# The above examples give you patterns that you can use to create new prompts (simple, complex, instruction etc.) - try creating other exercises to explore some of the other ideas we've talked about like examples, cues and more.
